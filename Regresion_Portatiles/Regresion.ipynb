# %% [markdown]
# #### Aquí encontrarás todo lo que necesitas saber: https://www.kaggle.com/competitions/desafio-de-prediccion-de-precios-de-portatiles

# %% [markdown]
# ## Librerias

# %%
import bootcampviztools as bt
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Data exploration

# %%
ruta = r"D:\DATASCIENCE\Repositorios\Kaggle_Desafio\Train\train.csv"
train = pd.read_csv(ruta, index_col="id")

# %%
train_copia = train.copy()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 912 entries, 268 to 1179
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         912 non-null    int64
#  1   Company           912 non-null    object
#  2   Product           912 non-null    object
#  3   TypeName          912 non-null    object
#  4   Inches            912 non-null    float64
#  5   ScreenResolution  912 non-null    object
#  6   Cpu               912 non-null    object
#  7   Ram               912 non-null    object
#  8   Memory            912 non-null    object
#  9   Gpu               912 non-null    object
#  10  OpSys             912 non-null    object
#  11  Weight            912 non-null    object
#  12  Price_euros       912 non-null    float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 99.8+ KB

# %%
train.TypeName.unique()
# Out:
# array(['Notebook', 'Gaming', 'Ultrabook', '2 in 1 Convertible', 'Netbook',
#        'Workstation'], dtype=object)

# %%
train.Ram.unique()
# Out:
# array(['8GB', '4GB', '16GB', '12GB', '6GB', '32GB', '2GB', '24GB'],
#       dtype=object)

# %%
train.Memory.unique()
# Out:
# array(['1TB HDD', '256GB SSD', '256GB SSD +  1TB HDD',
#        '512GB SSD +  2TB HDD', '128GB SSD +  1TB HDD', '128GB SSD',
#        '1TB SSD', '64GB Flash Storage', '2TB HDD', '500GB HDD',
#        '1.0TB Hybrid', '16GB Flash Storage', '256GB Flash Storage',
#        '180GB SSD', '32GB Flash Storage', '512GB SSD',
#        '512GB SSD +  1TB HDD', '256GB SSD +  500GB HDD',
#        '256GB SSD +  2TB HDD', '1TB SSD +  1TB HDD', '64GB SSD',
#        '128GB Flash Storage', '256GB SSD +  1.0TB Hybrid', '32GB SSD',
#        '512GB Flash Storage', '240GB SSD', '256GB SSD +  256GB SSD',
#        '16GB SSD', '8GB SSD', '64GB Flash Storage +  1TB HDD',
#        '1.0TB HDD', '1TB HDD +  1TB HDD', '512GB SSD +  512GB SSD',
#        '128GB SSD +  2TB HDD', '32GB HDD', '512GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
train.loc[train.TypeName == "Gaming"].max()
# Out:
# laptop_ID                                                    1277
# Company                                                     Razer
# Product                                              VivoBook Pro
# TypeName                                                   Gaming
# Inches                                                       18.4
# ScreenResolution    IPS Panel Touchscreen / 4K Ultra HD 3840x2160
# Cpu                                   Intel Core i7 7820HK 2.9GHz
# Ram                                                           8GB
# Memory                                       512GB SSD +  2TB HDD
# Gpu                                     Nvidia GeForce GTX1050 Ti
# OpSys                                                  Windows 10
# Weight                                                        4kg
# Price_euros                                                6099.0
# dtype: object

# %%
train.loc[train.TypeName == "Notebook"].max()
# Out:
# laptop_ID                                    1320
# Company                                    Xiaomi
# Product                    Zenbook UX510UW-FI095T
# TypeName                                 Notebook
# Inches                                       17.3
# ScreenResolution             Touchscreen 1366x768
# Cpu                 Intel Xeon E3-1535M v6 3.1GHz
# Ram                                           8GB
# Memory                                   64GB SSD
# Gpu                           Nvidia Quadro M620M
# OpSys                                   Windows 7
# Weight                                        3kg
# Price_euros                                4899.0
# dtype: object

# %%
train.loc[train.TypeName == "Gaming"].sort_values(by="Price_euros", ascending=True)
# Out:
#       laptop_ID Company                                  Product TypeName  \
# id
# 131          92    Asus  FX550IK-DM018T (FX-9830P/8GB/1TB/Radeon   Gaming
# 382         191  Lenovo                       Legion Y520-15IKBN   Gaming
# 227         373  Lenovo                       Legion Y520-15IKBN   Gaming
# 163        1208  Lenovo                       Legion Y520-15IKBN   Gaming
# 1270        708    Dell                            Inspiron 5577   Gaming
# ...         ...     ...                                      ...      ...
# 1167       1249   Razer                                Blade Pro   Gaming
# 333         789    Dell                             Alienware 17   Gaming
# 813         731    Dell                             Alienware 17   Gaming
# 73          839   Razer                                Blade Pro   Gaming
# 909         200   Razer                                Blade Pro   Gaming
#
#       Inches                     ScreenResolution  \
# id
# 131     15.6                    Full HD 1920x1080
# 382     15.6          IPS Panel Full HD 1920x1080
# 227     15.6          IPS Panel Full HD 1920x1080
# 163     15.6          IPS Panel Full HD 1920x1080
# 1270    15.6                    Full HD 1920x1080
# ...      ...                                  ...
# 1167    14.0                    Full HD 1920x1080
# 333     17.3          IPS Panel Full HD 1920x1080
# 813     17.3                4K Ultra HD 3840x2160
# 73      17.3  4K Ultra HD / Touchscreen 3840x2160
# 909     17.3  4K Ultra HD / Touchscreen 3840x2160
#
#                               Cpu   Ram                Memory  \
# id
# 131             AMD FX 9830P 3GHz   8GB               1TB HDD
# 382   Intel Core i5 7300HQ 2.5GHz   8GB             256GB SSD
# 227   Intel Core i5 7300HQ 2.5GHz   8GB  128GB SSD +  1TB HDD
# 163   Intel Core i5 7300HQ 2.5GHz   8GB               1TB HDD
# 1270  Intel Core i5 7300HQ 2.5GHz   8GB               1TB HDD
# ...                           ...   ...                   ...
# 1167  Intel Core i7 7700HQ 2.8GHz  16GB               1TB SSD
# 333   Intel Core i7 7700HQ 2.8GHz  32GB    1TB SSD +  1TB HDD
# 813   Intel Core i7 7700HQ 2.8GHz  32GB    1TB SSD +  1TB HDD
# 73    Intel Core i7 7820HK 2.9GHz  32GB             512GB SSD
# 909   Intel Core i7 7820HK 2.9GHz  32GB               1TB SSD
#
#                            Gpu       OpSys  Weight  Price_euros
# id
# 131          AMD Radeon RX 560  Windows 10  2.45kg        699.0
# 382    Nvidia GeForce GTX 1050       No OS   2.4kg        779.0
# 227    Nvidia GeForce GTX 1050       No OS   2.4kg        809.0
# 163    Nvidia GeForce GTX 1050  Windows 10   2.4kg        819.0
# 1270   Nvidia GeForce GTX 1050  Windows 10  2.56kg        819.0
# ...                        ...         ...     ...          ...
# 1167   Nvidia GeForce GTX 1060  Windows 10  1.95kg       3499.0
# 333   Nvidia GeForce GTX 1070M  Windows 10  4.42kg       3588.8
# 813    Nvidia GeForce GTX 1070  Windows 10  4.36kg       3659.4
# 73     Nvidia GeForce GTX 1080  Windows 10  3.49kg       5499.0
# 909    Nvidia GeForce GTX 1080  Windows 10  3.49kg       6099.0
#
# [138 rows x 13 columns]

# %%
train.loc[train.TypeName == "Notebook"].sort_values(by="Price_euros", ascending=True)
# Out:
#       laptop_ID Company                               Product  TypeName  \
# id
# 664         295    Acer                  Chromebook C910-C2ST  Notebook
# 1002         32    Asus  E402WA-GA010T (E2-6110/2GB/32GB/W10)  Notebook
# 526         800    Vero             K146 (N3350/4GB/32GB/W10)  Notebook
# 169        1117    Acer                         Chromebook 15  Notebook
# 1075       1055    Vero          V142 (X5-Z8350/2GB/32GB/W10)  Notebook
# ...         ...     ...                                   ...       ...
# 801        1064  Lenovo                           ThinkPad X1  Notebook
# 220         335    Dell                                XPS 15  Notebook
# 720        1031  Lenovo                          ThinkPad P70  Notebook
# 70          570  Lenovo                          Thinkpad P71  Notebook
# 518         617  Lenovo                          Thinkpad P51  Notebook
#
#       Inches                     ScreenResolution  \
# id
# 664     15.6                             1366x768
# 1002    14.0                             1366x768
# 526     14.0                            1920x1080
# 169     15.6                             1366x768
# 1075    14.0                             1366x768
# ...      ...                                  ...
# 801     14.0                  IPS Panel 2560x1440
# 220     15.6  4K Ultra HD / Touchscreen 3840x2160
# 720     17.3      IPS Panel 4K Ultra HD 3840x2160
# 70      17.3          IPS Panel Full HD 1920x1080
# 518     15.6      IPS Panel 4K Ultra HD 3840x2160
#
#                                        Cpu   Ram              Memory  \
# id
# 664   Intel Celeron Dual Core 3205U 1.5GHz   2GB            16GB SSD
# 1002           AMD E-Series E2-6110 1.5GHz   2GB  32GB Flash Storage
# 526   Intel Celeron Dual Core N3350 1.1GHz   4GB  32GB Flash Storage
# 169   Intel Celeron Dual Core 3205U 1.5GHz   4GB            16GB SSD
# 1075           Intel Atom X5-Z8350 1.44GHz   2GB  32GB Flash Storage
# ...                                    ...   ...                 ...
# 801             Intel Core i7 6600U 2.6GHz  16GB           256GB SSD
# 220            Intel Core i7 7700HQ 2.8GHz  32GB             1TB SSD
# 720            Intel Core i7 6820HQ 2.7GHz  16GB           512GB SSD
# 70             Intel Core i7 7700HQ 2.8GHz   8GB           256GB SSD
# 518          Intel Xeon E3-1535M v6 3.1GHz  32GB             1TB SSD
#
#                           Gpu       OpSys  Weight  Price_euros
# id
# 664         Intel HD Graphics   Chrome OS  2.19kg        199.0
# 1002            AMD Radeon R2  Windows 10  1.65kg        199.0
# 526     Intel HD Graphics 500  Windows 10  1.22kg        202.9
# 169         Intel HD Graphics   Chrome OS  2.20kg        209.0
# 1075    Intel HD Graphics 400  Windows 10  1.45kg        210.8
# ...                       ...         ...     ...          ...
# 801     Intel HD Graphics 520   Windows 7   1.1kg       2620.0
# 220   Nvidia GeForce GTX 1050  Windows 10  2.06kg       2639.0
# 720       Nvidia Quadro 3000M   Windows 7   2.4kg       2968.0
# 70        Nvidia Quadro M620M  Windows 10   3.4kg       2999.0
# 518      Nvidia Quadro M2200M  Windows 10   2.5kg       4899.0
#
# [522 rows x 13 columns]

# %%
train.head(10)
# Out:
#       laptop_ID  Company                                       Product  \
# id
# 268        1002     Dell                                 Inspiron 5567
# 347         867     Asus                    X541NA (N4200/4GB/1TB/W10)
# 353         966  Toshiba                             Portege Z30-C-1CW
# 578         767     Dell                                  Alienware 17
# 42         1241     Dell                                Latitude E7270
# 867         376     Asus                                  ZenBook Flip
# 1136         60     Asus  X541UA-DM1897 (i3-6006U/4GB/256GB/FHD/Linux)
# 609        1157      MSI                                    GP62M 7RDX
# 474         110     Asus    UX430UQ-GV209R (i7-7500U/8GB/256GB/GeForce
# 838        1263     Asus                            Rog GL553VE-FY052T
#
#                 TypeName  Inches                 ScreenResolution  \
# id
# 268             Notebook    15.6                         1366x768
# 347             Notebook    15.6                         1366x768
# 353             Notebook    13.3                Full HD 1920x1080
# 578               Gaming    15.6  IPS Panel 4K Ultra HD 3840x2160
# 42             Ultrabook    12.5  Full HD / Touchscreen 1920x1080
# 867   2 in 1 Convertible    15.6  Full HD / Touchscreen 1920x1080
# 1136            Notebook    15.6                Full HD 1920x1080
# 609               Gaming    15.6                Full HD 1920x1080
# 474            Ultrabook    14.0      IPS Panel Full HD 1920x1080
# 838               Gaming    15.6      IPS Panel Full HD 1920x1080
#
#                                        Cpu   Ram                Memory  \
# id
# 268             Intel Core i7 7500U 2.7GHz   8GB               1TB HDD
# 347   Intel Pentium Quad Core N4200 1.1GHz   4GB               1TB HDD
# 353             Intel Core i5 6200U 2.3GHz   8GB             256GB SSD
# 578            Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 42              Intel Core i5 6300U 2.4GHz   8GB             256GB SSD
# 867             Intel Core i7 7500U 2.7GHz  12GB  512GB SSD +  2TB HDD
# 1136              Intel Core i3 6006U 2GHz   4GB             256GB SSD
# 609            Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 474             Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 838            Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                              Gpu       OpSys  Weight  Price_euros
# id
# 268           AMD Radeon R7 M445  Windows 10  2.36kg       749.00
# 347        Intel HD Graphics 505  Windows 10     2kg       449.00
# 353        Intel HD Graphics 520   Windows 7   1.2kg      1460.00
# 578      Nvidia GeForce GTX 1070  Windows 10  4.42kg      2868.99
# 42         Intel HD Graphics 520   Windows 7  1.26kg      1713.37
# 867      Nvidia GeForce GT 940MX  Windows 10  2.26kg      1099.00
# 1136       Intel HD Graphics 520       Linux     2kg       415.00
# 609      Nvidia GeForce GTX 1050  Windows 10   2.4kg      1142.80
# 474         Nvidia GeForce 940MX  Windows 10   1.3kg      1193.00
# 838   Nvidia GeForce GTX 1050 Ti  Windows 10   2.5kg      1600.00

# %% [markdown]
# ## Data processing

# %% [markdown]
# ###LIMPIAR RESOLUCION

# %%
#EXTRACCION RESOLUCION DE PANTALLAS PARA LUEGO CLASIFICARLAS

patron = r'(\d{3,4}x\d{3,4})'  #Patron para extraer la resolucion solo

train["Resolucion"] = train['ScreenResolution'].str.extract(patron)

# %%
def clasificar_resolucion(valor):
    if valor == "640x480":
        return 'VGA'
    elif valor == "800x600":
        return 'SVGA'
    elif valor == "1024x768":
        return 'XGA'
    elif valor == "1366x768":
        return 'WXGA'
    elif valor == "1280 x 1024":
        return 'SXGA'
    elif valor == "1600x1200":
        return 'UXGA'
    elif valor == "1280x720":
        return 'HD'
    elif valor == "1920x1080":
        return 'FHD'
    elif valor == "2560x1440":
        return 'QHD'
    elif valor == "3840x2160":
        return '4K'
    elif valor == "5120x2880":
        return '5K'
    else:
        return 'Touch'

# %%
train['Pantalla'] = train['Resolucion'].apply(clasificar_resolucion)

# %%
train.head(50)
# Out:
#       laptop_ID  Company                                       Product  \
# id
# 268        1002     Dell                                 Inspiron 5567
# 347         867     Asus                    X541NA (N4200/4GB/1TB/W10)
# 353         966  Toshiba                             Portege Z30-C-1CW
# 578         767     Dell                                  Alienware 17
# 42         1241     Dell                                Latitude E7270
# 867         376     Asus                                  ZenBook Flip
# 1136         60     Asus  X541UA-DM1897 (i3-6006U/4GB/256GB/FHD/Linux)
# 609        1157      MSI                                    GP62M 7RDX
# 474         110     Asus    UX430UQ-GV209R (i7-7500U/8GB/256GB/GeForce
# 838        1263     Asus                            Rog GL553VE-FY052T
# 851        1243     Asus            X540SA-RBPDN09 (N3710/4GB/1TB/W10)
# 904          79     Dell                                 Inspiron 5570
# 355         957  Toshiba                               Tecra A50-C-1ZV
# 44          579       HP          15-cd005nv (A9-9420/6GB/256GB/Radeon
# 36          834  Toshiba                                 Satellite Pro
# 971          82     Dell                                 Latitude 5590
# 938         159   Lenovo                                Yoga 520-14IKB
# 718         332     Acer                                 Aspire E5-575
# 518         617   Lenovo                                  Thinkpad P51
# 1126        172     Acer                               Aspire A517-51G
# 51         1097   Lenovo                                     Yoga Book
# 772         717       HP          17-ak002nv (A10-9620P/6GB/2TB/Radeon
# 1001        814       HP                                 EliteBook 820
# 330         202       HP                                  Omen 17-W295
# 66          405     Dell                               Precision M5520
# 829          41     Asus     X540UA-DM186 (i3-6006U/4GB/1TB/FHD/Linux)
# 1129        741     Acer                           Extensa EX2540-58KR
# 1197        983   Lenovo                             IdeaPad 310-15IKB
# 171         407   Lenovo                             IdeaPad 320-15IAP
# 233         323       HP                                   ProBook 640
# 205         166     Dell                                 Inspiron 3576
# 361         309     Asus             GL553VE-FY082T (i7-7700HQ/8GB/1TB
# 1250       1276   Lenovo            B51-80 (i7-6500U/8GB/1008GB/Radeon
# 707         910     Dell                                   Vostro 3568
# 884         919     Acer                       Chromebook CB5-571-C1DZ
# 1071       1258   Lenovo                             IdeaPad 320-15ABR
# 95          895     Dell                                 Inspiron 3552
# 745        1190     Asus           X553SA-XX021T (N3050/4GB/500GB/W10)
# 899          37     Acer                                      Aspire 3
# 313         333     Asus                                  VivoBook S15
# 1063        933      MSI                                     GL62M 7RD
# 193        1066     Dell                                 Inspiron 5578
# 625          25       HP       15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)
# 142         429       HP                                   ProBook 650
# 243         685       HP                               Chromebook X360
# 1214        341       HP                                 EliteBook 840
# 1047         26     Dell                                 Inspiron 3567
# 648         882   Lenovo                             IdeaPad 110-15ISK
# 34            7    Apple                                   MacBook Pro
# 804        1100       HP                                 EliteBook 840
#
#                 TypeName  Inches                           ScreenResolution  \
# id
# 268             Notebook    15.6                                   1366x768
# 347             Notebook    15.6                                   1366x768
# 353             Notebook    13.3                          Full HD 1920x1080
# 578               Gaming    15.6            IPS Panel 4K Ultra HD 3840x2160
# 42             Ultrabook    12.5            Full HD / Touchscreen 1920x1080
# 867   2 in 1 Convertible    15.6            Full HD / Touchscreen 1920x1080
# 1136            Notebook    15.6                          Full HD 1920x1080
# 609               Gaming    15.6                          Full HD 1920x1080
# 474            Ultrabook    14.0                IPS Panel Full HD 1920x1080
# 838               Gaming    15.6                IPS Panel Full HD 1920x1080
# 851             Notebook    15.6                                   1366x768
# 904             Notebook    15.6                          Full HD 1920x1080
# 355             Notebook    15.6                                   1366x768
# 44              Notebook    15.6                IPS Panel Full HD 1920x1080
# 36              Notebook    14.0                                   1366x768
# 971            Ultrabook    15.6                IPS Panel Full HD 1920x1080
# 938   2 in 1 Convertible    14.0  IPS Panel Full HD / Touchscreen 1920x1080
# 718             Notebook    15.6                                   1366x768
# 518             Notebook    15.6            IPS Panel 4K Ultra HD 3840x2160
# 1126            Notebook    17.3                IPS Panel Full HD 1920x1080
# 51    2 in 1 Convertible    10.1            IPS Panel Touchscreen 1920x1200
# 772             Notebook    17.3                IPS Panel Full HD 1920x1080
# 1001             Netbook    12.5                                   1366x768
# 330               Gaming    17.3                IPS Panel Full HD 1920x1080
# 66           Workstation    15.6        4K Ultra HD / Touchscreen 3840x2160
# 829             Notebook    15.6                          Full HD 1920x1080
# 1129            Notebook    15.6                                   1366x768
# 1197            Notebook    15.6                          Full HD 1920x1080
# 171             Notebook    15.6                                   1366x768
# 233             Notebook    14.0                          Full HD 1920x1080
# 205             Notebook    15.6                          Full HD 1920x1080
# 361               Gaming    15.6                          Full HD 1920x1080
# 1250            Notebook    15.6                          Full HD 1920x1080
# 707             Notebook    15.6                                   1366x768
# 884             Notebook    15.6                IPS Panel Full HD 1920x1080
# 1071            Notebook    15.6                          Full HD 1920x1080
# 95              Notebook    15.6                                   1366x768
# 745             Notebook    15.6                                   1366x768
# 899             Notebook    15.6                                   1366x768
# 313            Ultrabook    15.6                          Full HD 1920x1080
# 1063              Gaming    15.6                          Full HD 1920x1080
# 193   2 in 1 Convertible    15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 625            Ultrabook    15.6                          Full HD 1920x1080
# 142             Notebook    15.6                          Full HD 1920x1080
# 243   2 in 1 Convertible    11.6                       Touchscreen 1366x768
# 1214            Notebook    14.0                          Full HD 1920x1080
# 1047            Notebook    15.6                                   1366x768
# 648             Notebook    15.6                          Full HD 1920x1080
# 34             Ultrabook    15.4         IPS Panel Retina Display 2880x1800
# 804             Notebook    14.0                          Full HD 1920x1080
#
#                                        Cpu   Ram                Memory  \
# id
# 268             Intel Core i7 7500U 2.7GHz   8GB               1TB HDD
# 347   Intel Pentium Quad Core N4200 1.1GHz   4GB               1TB HDD
# 353             Intel Core i5 6200U 2.3GHz   8GB             256GB SSD
# 578            Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 42              Intel Core i5 6300U 2.4GHz   8GB             256GB SSD
# 867             Intel Core i7 7500U 2.7GHz  12GB  512GB SSD +  2TB HDD
# 1136              Intel Core i3 6006U 2GHz   4GB             256GB SSD
# 609            Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 474             Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 838            Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 851   Intel Pentium Quad Core N3710 1.6GHz   4GB               1TB HDD
# 904             Intel Core i7 8550U 1.8GHz   8GB  128GB SSD +  1TB HDD
# 355             Intel Core i5 6200U 2.3GHz   8GB             256GB SSD
# 44              AMD A9-Series A9-9420 3GHz   6GB             256GB SSD
# 36    Intel Pentium Dual Core 4405U 2.1GHz   4GB             128GB SSD
# 971             Intel Core i5 8250U 1.6GHz   8GB             256GB SSD
# 938             Intel Core i3 7100U 2.4GHz   4GB             256GB SSD
# 718             Intel Core i5 7200U 2.5GHz   6GB               1TB HDD
# 518          Intel Xeon E3-1535M v6 3.1GHz  32GB               1TB SSD
# 1126            Intel Core i5 8250U 1.6GHz   8GB             256GB SSD
# 51             Intel Atom x5-Z8550 1.44GHz   4GB    64GB Flash Storage
# 772            AMD A10-Series 9620P 2.5GHz   6GB               2TB HDD
# 1001            Intel Core i5 7300U 2.6GHz   8GB             256GB SSD
# 330            Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 66             Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 829               Intel Core i3 6006U 2GHz   4GB               1TB HDD
# 1129            Intel Core i5 7200U 2.5GHz   4GB             500GB HDD
# 1197            Intel Core i5 7200U 2.5GHz   6GB             256GB SSD
# 171   Intel Celeron Dual Core N3350 1.1GHz   4GB               1TB HDD
# 233             Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 205             Intel Core i5 8250U 1.6GHz   8GB             256GB SSD
# 361            Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 1250            Intel Core i7 6500U 2.5GHz   8GB          1.0TB Hybrid
# 707             Intel Core i3 6006U 2.0GHz   4GB               1TB HDD
# 884   Intel Celeron Dual Core 3205U 1.5GHz   4GB    16GB Flash Storage
# 1071           AMD A12-Series 9720P 3.6GHz   6GB             256GB SSD
# 95    Intel Pentium Quad Core N3710 1.6GHz   4GB             500GB HDD
# 745   Intel Celeron Dual Core N3050 1.6GHz   4GB             500GB HDD
# 899             Intel Core i3 7130U 2.7GHz   4GB               1TB HDD
# 313             Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 1063           Intel Core i5 7300HQ 2.5GHz   8GB  128GB SSD +  1TB HDD
# 193             Intel Core i5 7200U 2.7GHz   8GB             256GB SSD
# 625             Intel Core i7 8550U 1.8GHz   8GB             256GB SSD
# 142            Intel Core i7 7820HQ 2.9GHz   8GB             256GB SSD
# 243   Intel Celeron Dual Core N3350 1.1GHz   8GB    64GB Flash Storage
# 1214            Intel Core i5 7300U 2.6GHz   8GB             256GB SSD
# 1047              Intel Core i3 6006U 2GHz   4GB               1TB HDD
# 648               Intel Core i3 6006U 2GHz   4GB               1TB HDD
# 34                    Intel Core i7 2.2GHz  16GB   256GB Flash Storage
# 804             Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
#
#                              Gpu       OpSys  Weight  Price_euros Resolucion  \
# id
# 268           AMD Radeon R7 M445  Windows 10  2.36kg       749.00   1366x768
# 347        Intel HD Graphics 505  Windows 10     2kg       449.00   1366x768
# 353        Intel HD Graphics 520   Windows 7   1.2kg      1460.00  1920x1080
# 578      Nvidia GeForce GTX 1070  Windows 10  4.42kg      2868.99  3840x2160
# 42         Intel HD Graphics 520   Windows 7  1.26kg      1713.37  1920x1080
# 867      Nvidia GeForce GT 940MX  Windows 10  2.26kg      1099.00  1920x1080
# 1136       Intel HD Graphics 520       Linux     2kg       415.00  1920x1080
# 609      Nvidia GeForce GTX 1050  Windows 10   2.4kg      1142.80  1920x1080
# 474         Nvidia GeForce 940MX  Windows 10   1.3kg      1193.00  1920x1080
# 838   Nvidia GeForce GTX 1050 Ti  Windows 10   2.5kg      1600.00  1920x1080
# 851        Intel HD Graphics 405  Windows 10  2.65kg       309.00   1366x768
# 904       Intel UHD Graphics 620  Windows 10  2.02kg       855.00  1920x1080
# 355        Intel HD Graphics 520  Windows 10   2.2kg      1119.00   1366x768
# 44                AMD Radeon 530  Windows 10  1.95kg       649.00  1920x1080
# 36         Intel HD Graphics 510  Windows 10  1.75kg       499.00   1366x768
# 971       Intel UHD Graphics 620  Windows 10  1.88kg      1096.16  1920x1080
# 938        Intel HD Graphics 620  Windows 10  1.74kg       629.00  1920x1080
# 718        Intel HD Graphics 620  Windows 10  2.23kg       549.00   1366x768
# 518         Nvidia Quadro M2200M  Windows 10   2.5kg      4899.00  3840x2160
# 1126        Nvidia GeForce MX150  Windows 10     3kg       854.00  1920x1080
# 51         Intel HD Graphics 400  Windows 10  0.69kg       646.27  1920x1200
# 772               AMD Radeon 530  Windows 10  2.71kg       655.01  1920x1080
# 1001       Intel HD Graphics 620  Windows 10  1.26kg      1389.00   1366x768
# 330      Nvidia GeForce GTX 1050  Windows 10  3.35kg      1379.00  1920x1080
# 66           Nvidia Quadro M1200  Windows 10  1.78kg      2712.00  3840x2160
# 829        Intel HD Graphics 620       Linux     2kg       389.00  1920x1080
# 1129       Intel HD Graphics 620  Windows 10   2.4kg       559.00   1366x768
# 1197        Nvidia GeForce 920MX  Windows 10   2.4kg       695.00  1920x1080
# 171        Intel HD Graphics 500  Windows 10   2.2kg       306.00   1366x768
# 233        Intel HD Graphics 620  Windows 10  1.95kg       980.00  1920x1080
# 205               AMD Radeon 520  Windows 10  2.13kg       728.00  1920x1080
# 361   Nvidia GeForce GTX 1050 Ti  Windows 10   2.5kg      1265.00  1920x1080
# 1250          AMD Radeon R5 M330   Windows 7  2.32kg       895.00  1920x1080
# 707          AMD Radeon R5 M420X  Windows 10  2.18kg       614.00   1366x768
# 884            Intel HD Graphics   Chrome OS  2.20kg       359.00  1920x1080
# 1071              AMD Radeon 530  Windows 10   2.2kg       597.57  1920x1080
# 95             Intel HD Graphics  Windows 10   2.2kg       369.00   1366x768
# 745            Intel HD Graphics  Windows 10   2.2kg       369.00   1366x768
# 899        Intel HD Graphics 620       Linux   2.1kg       367.00   1366x768
# 313         Nvidia GeForce 940MX  Windows 10   1.7kg      1049.90  1920x1080
# 1063     Nvidia GeForce GTX 1050  Windows 10   2.2kg      1119.91  1920x1080
# 193        Intel HD Graphics 620  Windows 10   2.3kg      1094.00  1920x1080
# 625        Intel HD Graphics 620  Windows 10  1.91kg       659.00  1920x1080
# 142        Intel HD Graphics 630  Windows 10  2.31kg      1427.00  1920x1080
# 243        Intel HD Graphics 500   Chrome OS   1.4kg       495.00   1366x768
# 1214       Intel HD Graphics 620  Windows 10  1.48kg      1268.00  1920x1080
# 1047       Intel HD Graphics 520  Windows 10   2.3kg       418.64   1366x768
# 648           AMD Radeon R5 M430       No OS   2.2kg       479.00  1920x1080
# 34       Intel Iris Pro Graphics    Mac OS X  2.04kg      2139.97  2880x1800
# 804        Intel HD Graphics 520   Windows 7  1.54kg      1030.99  1920x1080
#
#      Pantalla
# id
# 268      WXGA
# 347      WXGA
# 353       FHD
# 578        4K
# 42        FHD
# 867       FHD
# 1136      FHD
# 609       FHD
# 474       FHD
# 838       FHD
# 851      WXGA
# 904       FHD
# 355      WXGA
# 44        FHD
# 36       WXGA
# 971       FHD
# 938       FHD
# 718      WXGA
# 518        4K
# 1126      FHD
# 51      Touch
# 772       FHD
# 1001     WXGA
# 330       FHD
# 66         4K
# 829       FHD
# 1129     WXGA
# 1197      FHD
# 171      WXGA
# 233       FHD
# 205       FHD
# 361       FHD
# 1250      FHD
# 707      WXGA
# 884       FHD
# 1071      FHD
# 95       WXGA
# 745      WXGA
# 899      WXGA
# 313       FHD
# 1063      FHD
# 193       FHD
# 625       FHD
# 142       FHD
# 243      WXGA
# 1214      FHD
# 1047     WXGA
# 648       FHD
# 34      Touch
# 804       FHD

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Pasos que si o si debéis realizar para poder participar en la competición:

# %% [markdown]
# ### 1. Definir X e y

# %% [markdown]
# ### 2. Dividir X_train, X_test, y_train, y_test

# %% [markdown]
# ### 3. Crear y entrenar el modelo

# %% [markdown]
# ### 4. Sacar métricas, valorar el modelo
#
# Recuerda que en la competición se va a evaluar con la métrica de MAE.

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# ## Una vez listo el modelo, toca predecir con el dataset de predicción

# %% [markdown]
# Definición de **modelo que está listo**.
#
# Tras hacer suficientes pruebas, analizar los datos, hacer feature engineering, probar diferentes modelos con diferentes parámetros, es con este con el que observo mejores métricas y menos overfitting. ¡Cuidado con el overfitting aquí! Si vuestro modelo aprende muy bien de estos datos pero hay overfitting cuando le pasemos los datos desconocidos de `test.csv` nos arriesgamos a que digamos, no salga lo esperado.

# %% [markdown]
# ### 1. Entrena dicho modelo con TODOS tus datos de train, esto es con `train.csv` al completo.
#
#
# **CON LAS TRANSFORMACIONES QUE LE HAYAS REALIZADO A `X` INCLUÍDAS.**
#
#
# Véase:
# - Estandarización/Normalización
# - Eliminación de Outliers
# - Eliminación de columnas
# - Creación de columnas nuevas
# - Gestión de valores nulos
# - Y un largo etcétera de técnicas que como Data Scientist hayas considerado las mejores para tu dataset.

# %% [markdown]
# ### 2. Carga los datos de `test.csv` para predecir.

# %% [markdown]
# **¿Por qué puede dar error?**

# %% [markdown]
# IMPORTANTE: APLICAR A ESTOS DATOS LO MISMO QUE HAYÁIS APLICADO A LOS DATOS DE ENTRENAMIENTO
#
# - SI EL ARRAY CON EL QUE HICISTEIS `.fit()` ERA DE 4 COLUMNAS, PARA `.predict()` DEBEN SER LAS MISMAS
# - SI AL ARRAY CON EL QUE HICISTEIS `.fit()` LO NORMALIZASTEIS, PARA `.predict()` DEBÉIS NORMALIZARLO
# - TODO IGUAL SALVO BORRAR FILAS, EL NÚMERO DE ROWS SE DEBE MANTENER EN ESTE SET, PUES LA PREDICCIÓN DEBE TENER 391 FILAS, SI O SI

# %% [markdown]
# **Entonces, si al cargar los datos de train usé `index_col=0` para que utilizara la primera columna del conjunto de datos como índice, ¿tendré que hacerlo también para el conjunto `test.csv`?**

# %%
# ¿Qué opináis?
# Sí

# %% [markdown]
# ![](https://www.tierraljelechu.com/web/img/wiki_up/1.996-SorpresaDto.-1-Red.jpg)

# %% [markdown]
# ### 3. AHORA puedo hacer la predicción que será lo que subirás a Kaggle.

# %% [markdown]
# **¿Qué es lo que subirás a Kaggle?**

# %%
predictions = model.predict(X_pred)
predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[173], line 1
# ----> 1 predictions = model.predict(X_pred)
#       2 predictions
#
# NameError: name 'model' is not defined

# %% [markdown]
# **¡PERO! Para subir a Kaggle la predicción, ésta tendrá que tener una forma específica y no valdrá otra.**
#
# En este caso, la **MISMA** forma que `sample_submission.csv`.

# %%
sample = pd.read_csv("Dataset/sample_submission.csv") # Esta es mi ruta del archivo, la vuestra puede ser otra

# %%
sample.head()

# %%
sample.shape

# %% [markdown]
# ### 4. Mete tus predicciones en un dataframe.
#
# En este caso, la **MISMA** forma que `sample_submission.csv`.

# %% [markdown]
# ### 5. Pásale el CHEQUEATOR para comprobar que efectivamente está listo para subir a Kaggle.

# %%
def chequeator(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.id.all() == sample.id.all():
                print("You're ready to submit!")
                submission.to_csv("submission.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("")

# %%
chequeator(submission) # submission es el nombre que le habríamos puesto a nuestro .csv con los valores que me salieron en la predicción
# Out:
# You're ready to submit!
